# %% [markdown]
# ## This is the visualization report for our project HMDA Mortgage Analysis and Prediction

# %% [markdown]
# ### 1. EDA

# %%
# %matplotlib inline

# %%
run src/data_processing/DownScale.py
# Out:
# Save the updated data set with coded only and decisions of approve/denial to /data/csvs/hmda_2017_ca_noname.csv

# %% [markdown]
# 1. Gender analysis

# %%
run src/visualizations/Gender_analysis.py
# Out:
# Finished Generating Gender Analysis Plots For All applicant
# Finished Generating Gender Analysis plots For co-applicant condition analysis
# Finished Generating Gender Analysis plots For Applicant Pairs analysis

# %% [markdown]
# 2. Race and Ethnicity Analysis

# %%
run src/visualizations/Race_analysis.py
# Out:
# Finished Generating Race Analysis Plots For All applicant
# Finished Generating Race Analysis plots For co-applicant condition analysis

# %%
run src/visualizations/Ethnicity_analysis.py
# Out:
# Finished Generating Ethnicity Analysis Plots For All applicant
# Finished Generating Ethnicity Analysis plots For co-applicant condition analysis
# Finished Generating Ethnicity Analysis plots For Applicant Pairs analysis

# %% [markdown]
# 3. Income analysis

# %%
run src/visualizations/Income_analysis.py
# Out:
# E:\test143\src\visualizations\Income_analysis.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   #print(income_b)
# E:\test143\src\visualizations\Income_analysis.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   income_a1.plot.bar(title='Application Result Counts vs Income')

# %% [markdown]
# ### 2. Predictive Model
